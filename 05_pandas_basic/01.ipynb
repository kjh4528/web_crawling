# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '3.0.2'

# %%
name_series = pd.Series(['앨리스','밥'], name='이름')
name_series
# Out:
# 0    앨리스
# 1      밥
# Name: 이름, dtype: str

# %%
df = pd.DataFrame({
    '이름':['앨리스','밥'],
    '나이':[25, 30]
})

df
# Out:
#     이름  나이
# 0  앨리스  25
# 1    밥  30

# %%
df = pd.DataFrame({
    '제품':['키보드','마우스','모니터'],
    '가격':[25000,10000,22000],
    '재고':[10,0,4]
})

df
# Out:
#     제품     가격  재고
# 0  키보드  25000  10
# 1  마우스  10000   0
# 2  모니터  22000   4

# %%
is_stock = df[(df['재고'] > 0) & (df['가격'] > 22000)]
is_stock
# Out:
#     제품     가격  재고
# 0  키보드  25000  10

# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

tips.shape # 데이터 크기 확인
# Out:
# (244, 7)

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
# 주말이면서 저녁인 데이터 분석
weekend_dinner = tips[(tips['time'] == 'Dinner') & (tips['day'].isin(['Sat', 'Sun'])) ]
weekend_dinner
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 0         16.99  1.01  Female     No  Sun  Dinner     2
# 1         10.34  1.66    Male     No  Sun  Dinner     3
# 2         21.01  3.50    Male     No  Sun  Dinner     3
# 3         23.68  3.31    Male     No  Sun  Dinner     2
# 4         24.59  3.61  Female     No  Sun  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3
# 239       29.03  5.92    Male     No  Sat  Dinner     3
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2
# 242       17.82  1.75    Male     No  Sat  Dinner     2
#
# [163 rows x 7 columns]

# %%
weekend_dinner1 = tips.query("day =='Sat' or day == 'Sun' and 'time' == 'Dinner'")
weekend_dinner1
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 19        20.65  3.35    Male     No  Sat  Dinner     3
# 20        17.92  4.08    Male     No  Sat  Dinner     2
# 21        20.29  2.75  Female     No  Sat  Dinner     2
# 22        15.77  2.23  Female     No  Sat  Dinner     2
# 23        39.42  7.58    Male     No  Sat  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3
# 239       29.03  5.92    Male     No  Sat  Dinner     3
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2
# 242       17.82  1.75    Male     No  Sat  Dinner     2
#
# [87 rows x 7 columns]

# %%
# 일요일이 아니고 총 결제금액이 20달러 이상인 데이터 분석 
notsun_highbill = tips.query("day != 'Sun' and total_bill >= 20")
notsun_highbill
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 19        20.65   3.35    Male     No   Sat  Dinner     3
# 21        20.29   2.75  Female     No   Sat  Dinner     2
# 23        39.42   7.58    Male     No   Sat  Dinner     4
# 28        21.70   4.30    Male     No   Sat  Dinner     2
# 33        20.69   2.45  Female     No   Sat  Dinner     4
# 35        24.06   3.60    Male     No   Sat  Dinner     3
# 39        31.27   5.00    Male     No   Sat  Dinner     3
# 56        38.01   3.00    Male    Yes   Sat  Dinner     4
# 57        26.41   1.50  Female     No   Sat  Dinner     2
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 60        20.29   3.21    Male    Yes   Sat  Dinner     2
# 65        20.08   3.15    Male     No   Sat  Dinner     3
# 68        20.23   2.01    Male     No   Sat  Dinner     2
# 72        26.86   3.14  Female    Yes   Sat  Dinner     2
# 73        25.28   5.00  Female    Yes   Sat  Dinner     2
# ...

# %%
student_df = pd.DataFrame({
    '이름':['민지','서준',None,'도윤'],
    '나이':[25, np.nan, 31,28]
})
student_df
# Out:
#     이름    나이
# 0   민지  25.0
# 1   서준   NaN
# 2  NaN  31.0
# 3   도윤  28.0

# %%
# 결측치 탐지
print(student_df.isnull())
print(student_df.isna())
print(student_df.notnull())
# Out:
#       이름     나이
# 0  False  False
# 1  False   True
# 2   True  False
# 3  False  False
#       이름     나이
# 0  False  False
# 1  False   True
# 2   True  False
# 3  False  False
#       이름     나이
# 0   True   True
# 1   True  False
# 2  False   True
# 3   True   True

# %%
# 결측치 개수 확인
student_df.isnull().sum()

# 결측지 제외 데이터 개수 확인
student_df.notnull().sum()
# Out:
# 이름    3
# 나이    3
# dtype: int64

# %%
# 결측치 볼 때에는 결측률 구해서 확인

student_df.isna().sum() / len(student_df)
# Out:
# 이름    0.25
# 나이    0.25
# dtype: float64

# %%
# 결측치 제거
# 결측치 제거시 결측치가 속한 행이 제거됨
# 행: 정보의 최소 단위 
student_df.dropna()

# 원본 불변의 법칙 -> 결측치 제거한 데이터프레임이 반환되지만 원본 데이터프레임은 그대로 유지됨
# 새로운 변수에 저장
# Out:
#    이름    나이
# 0  민지  25.0
# 3  도윤  28.0

# %%
student_df['과제'] = [19, np.nan, 20, 17]
student_df['시험점수'] = [88.0, 92.0, np. nan, 75.0]
student_df
# Out:
#     이름    나이    과제  시험점수
# 0   민지  25.0  19.0  88.0
# 1   서준   NaN   NaN  92.0
# 2  NaN  31.0  20.0   NaN
# 3   도윤  28.0  17.0  75.0

# %%
# 의미있는 값으로 대체하기
student_df['과제'].fillna(student_df['과제'].mean())
# Out:
# 0    19.000000
# 1    18.666667
# 2    20.000000
# 3    17.000000
# Name: 과제, dtype: float64

# %%
data = {"고객ID": ["C001","C002","C003"], "나이": [25,31,28], "가입여부": [True, False, True]}
df = pd.DataFrame(data)
print(df.columns.tolist())
print(df.dtypes)
# Out:
# ['고객ID', '나이', '가입여부']
# 고객ID      str
# 나이      int64
# 가입여부     bool
# dtype: object

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from pathlib import Path


def load_csv(filename):
    candidates = [Path(filename), Path.cwd() / filename]
    candidates.extend(Path.cwd().rglob(filename))

    seen = set()
    for path in candidates:
        key = str(path)
        if key in seen:
            continue
        seen.add(key)
        if path.exists():
            return pd.read_csv(path)

    raise FileNotFoundError(f"{filename} 파일을 찾지 못했어요.")


def load_tips():
    try:
        return sns.load_dataset("tips")
    except Exception:
        return load_csv("tips.csv")


def load_telco():
    filenames = [
        "WA_Fn-UseC_-Telco-Customer-Churn.csv",
        "telco_churn.csv",
        "Telco-Customer-Churn.csv",
    ]

    for filename in filenames:
        try:
            return load_csv(filename)
        except FileNotFoundError:
            continue

    raise FileNotFoundError("Telco Churn CSV 파일을 찾지 못했어요.")

# %%
telco= load_telco()
telco.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...
